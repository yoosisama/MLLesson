# %% [markdown]
# [Graphviz公式サイトより](https://pypi.python.org/pypi/graphviz)
#
# [Getting started with Graphviz and Python](http://matthiaseisen.com/articles/graphviz/)
#
# [graphviz github](https://github.com/xflr6/graphviz)

# %%
from graphviz import Digraph
import PIL.Image

# %%
d = Digraph()
d.edge("hello","world")
d

# %%
d = Digraph()
d.graph_attr['rankdir']='LR'
d.edge("hello","world")
d

# %%
d = Digraph(node_attr={'shape':'plaintext'})
d.graph_attr['rankdir']='LR'
d.edge_attr.update(arrowhead='vee',arrowsize='2')
d.edge("hello","world")
d

# %%
dot = Digraph(comment='The Round Table',format="png")
dot.graph_attr['rankdir'] = 'LR'

def jnode(g, n1,n2):
    g.node(n1,n2)

jnode(dot,'A', 'アーサー王')
jnode(dot,'B', '賢明なるベディヴィア卿')
jnode(dot,'L', '勇猛なるランスロット卿')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='False')
print(dot.source)
dot.render('aser')
PIL.Image.open('aser.png')
# Out:
# // The Round Table
# digraph {
# 	graph [rankdir=LR]
# 	A [label="アーサー王"]
# 	B [label="賢明なるベディヴィア卿"]
# 	L [label="勇猛なるランスロット卿"]
# 	A -> B
# 	A -> L
# 	B -> L [constraint=False]
# }
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=469x131 at 0x215ED032E48>

# %%
dot = Digraph(comment='The Round Table',format="png")
dot.graph_attr['rankdir'] = 'LR'

def jnode(g, n1,n2):
    g.node(n1,n2, fontname="Meiryo Bold")

jnode(dot,'A', 'アーサー王')
jnode(dot,'B', '賢明なるベディヴィア卿')
jnode(dot,'L', '勇猛なるランスロット卿')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='False')
print(dot.source)
dot.render('aser')
PIL.Image.open('aser.png')
# Out:
# // The Round Table
# digraph {
# 	graph [rankdir=LR]
# 	A [label="アーサー王" fontname="Meiryo Bold"]
# 	B [label="賢明なるベディヴィア卿" fontname="Meiryo Bold"]
# 	L [label="勇猛なるランスロット卿" fontname="Meiryo Bold"]
# 	A -> B
# 	A -> L
# 	B -> L [constraint=False]
# }
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=511x131 at 0x215ED0B9898>

# %% [markdown]
# png画像として保存してから表示

# %%
dot.render('test-output/round-table.gv', view=False)  # True にすると別ウィンドウが開いて描画される 
PIL.Image.open('test-output/round-table.gv.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=511x131 at 0x215ED0B9E10>

# %%
G = Digraph(format="png")
G.attr("node", shape="circle", style="filled",rankdir='LR')
# G.graph_attr['rankdir'] = 'LR'
G.graph_attr['shape'] = 'Box'
G.node("out0",label="0")
G.node("in0",label="0")
G.node("in1",label="1")
G.node("out1",label="1")
G.edge("in0","out0",label="0.8")
G.edge("in0","out1",label="0.2")
G.edge("in1","out0",label="0.2")
G.edge("in1","out1",label="0.8")
G.render("pic0")

PIL.Image.open('pic0.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=176x175 at 0x215EBE871D0>

# %%
G.source
# Out:
# 'digraph {\n\tgraph [shape=Box]\n\tnode [rankdir=LR shape=circle style=filled]\n\tout0 [label=0]\n\tin0 [label=0]\n\tin1 [label=1]\n\tout1 [label=1]\n\tin0 -> out0 [label=0.8]\n\tin0 -> out1 [label=0.2]\n\tin1 -> out0 [label=0.2]\n\tin1 -> out1 [label=0.8]\n}'

# %%
g = Digraph('g', filename='btree.gv', node_attr={'shape': 'record', 'height': '.1'},format="png")

g.node('node0', '<f0> |<f1> A|<f2> ')
g.node('node1', '<f0> |<f1> E|<f2> ')
g.node('node2', '<f0> |<f1> B|<f2> ')
g.node('node3', '<f0> |<f1> F|<f2> ')
g.node('node4', '<f0> |<f1> R|<f2> ')
g.node('node5', '<f0> |<f1> H|<f2> ')
g.node('node6', '<f0> |<f1> Y|<f2> ')
g.node('node7', '<f0> |<f1> A|<f2> ')
g.node('node8', '<f0> |<f1> C|<f2> ')

g.edge('node0:f2', 'node4:f1')
g.edge('node0:f0', 'node1:f1')
g.edge('node1:f0', 'node2:f1')
g.edge('node1:f2', 'node3:f1')
g.edge('node2:f2', 'node8:f1')
g.edge('node2:f0', 'node7:f1')
g.edge('node4:f2', 'node6:f1')
g.edge('node4:f0', 'node5:f1')

g.render('pic1')
PIL.Image.open('pic1.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=491x283 at 0x215ED0F1978>

# %%
from graphviz import Graph

#必要なモジュールのインポート
import numpy as np
import pydotplus

def neuralViz(shape, fileName='default.png', plot=True, Wlist=None):
      
    args = np.array(shape)
    matrix = np.zeros((args.sum(), args.sum()))
           
    #結ぶノード間に１を入力
    for i in range(len(args)-1):
        tmp1 = args[:i+1].sum()
        tmp0 = args[:i].sum()
        matrix[tmp1:tmp1+args[i+1],tmp0:tmp0+args[i]] = 1  
                    
    #描画
    g=pydotplus.graph_from_adjacency_matrix(matrix.T.tolist(), node_prefix=0)
  
    #何もしないとNodeが作られないので足す。ついでに文字を消す。
    #for i in range(args.sum()-10):
    for i in range(args.sum()):
        n = pydotplus.Node(i+1)
        n.set_fontsize(0)
        g.add_node(n)

        if plot == True:
        #グラフ書き出し（'default.png'）    
            g.write_png(fileName, prog='dot')
    return g

# %%
g = neuralViz([3, 4, 6, 3, 2, 5])

# %%
import PIL.Image
PIL.Image.open('default.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=563x539 at 0x215ED0B9BA8>

# %% [markdown]
# [PythonでGraphvizを使ってニューラルネットワークを描画する](https://goo.gl/XWkU9Z)

# %%
g.to_string()
# Out:
# 'graph G {\n1 -- 4;\n1 -- 5;\n1 -- 6;\n1 -- 7;\n2 -- 4;\n2 -- 5;\n2 -- 6;\n2 -- 7;\n3 -- 4;\n3 -- 5;\n3 -- 6;\n3 -- 7;\n4 -- 8;\n4 -- 9;\n4 -- 10;\n4 -- 11;\n4 -- 12;\n4 -- 13;\n5 -- 8;\n5 -- 9;\n5 -- 10;\n5 -- 11;\n5 -- 12;\n5 -- 13;\n6 -- 8;\n6 -- 9;\n6 -- 10;\n6 -- 11;\n6 -- 12;\n6 -- 13;\n7 -- 8;\n7 -- 9;\n7 -- 10;\n7 -- 11;\n7 -- 12;\n7 -- 13;\n8 -- 14;\n8 -- 15;\n8 -- 16;\n9 -- 14;\n9 -- 15;\n9 -- 16;\n10 -- 14;\n10 -- 15;\n10 -- 16;\n11 -- 14;\n11 -- 15;\n11 -- 16;\n12 -- 14;\n12 -- 15;\n12 -- 16;\n13 -- 14;\n13 -- 15;\n13 -- 16;\n14 -- 17;\n14 -- 18;\n15 -- 17;\n15 -- 18;\n16 -- 17;\n16 -- 18;\n17 -- 19;\n17 -- 20;\n17 -- 21;\n17 -- 22;\n17 -- 23;\n18 -- 19;\n18 -- 20;\n18 -- 21;\n18 -- 22;\n18 -- 23;\n1 [fontsize=0];\n2 [fontsize=0];\n3 [fontsize=0];\n4 [fontsize=0];\n5 [fontsize=0];\n6 [fontsize=0];\n7 [fontsize=0];\n8 [fontsize=0];\n9 [fontsize=0];\n10 [fontsize=0];\n11 [fontsize=0];\n12 [fontsize=0];\n13 [fontsize=0];\n14 [fontsize=0];\n15 [fontsize=0];\n16 [fontsize=0];\n17 [fontsize=0];\n18 [fontsize=0];\n19 [fontsize=0];\n20 [fontsize=0];\n21 [fontsize=0];\n22 [fontsize=0];\n23 [fontsize=0];\n}\n'

# %%
from graphviz import Source
gr = Source(g.to_string())
gr

# %%
# angles.py - http://www.graphviz.org/Gallery/gradient/angles.html

from graphviz import Digraph

g = Digraph('G', format='png')
g.attr(bgcolor='blue')

with g.subgraph(name='cluster_1') as c:
    c.attr(fontcolor='white')
    c.attr('node', shape='circle', style='filled', fillcolor='white:black',
           gradientangle='360', label='n9:360', fontcolor='black')
    c.node('n9')
    for i, a in zip(range(8, 0, -1), range(360 - 45, -1, -45)):
        c.attr('node', gradientangle='%d' % a, label='n%d:%d' % (i, a))
        c.node('n%d' % i)
    c.attr(label='Linear Angle Variations (white to black gradient)')

with g.subgraph(name='cluster_2') as c:
    c.attr(fontcolor='white')
    c.attr('node', shape='circle', style='radial', fillcolor='white:black',
           gradientangle='360', label='n18:360', fontcolor='black')
    c.node('n18')
    for i, a in zip(range(17, 9, -1), range(360 - 45, -1, -45)):
        c.attr('node', gradientangle='%d' % a, label='n%d:%d' % (i, a))
        c.node('n%d' % i)
    c.attr(label='Radial Angle Variations (white to black gradient)')

g.edge('n5', 'n14')

# g.view()
g.render('angles')
PIL.Image.open('angles.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1135x343 at 0x215ED8BBA58>

# %%
g = Digraph('G', format="png")

# NOTE: the subgraph name needs to begin with 'cluster' (all lowercase)
#       so that Graphviz recognizes it as a special cluster subgraph

with g.subgraph(name='cluster_0') as c:
    c.attr(style='filled')
    c.attr(color='lightgrey')
    c.node_attr.update(style='filled', color='white')
    c.edges([('a0', 'a1'), ('a1', 'a2'), ('a2', 'a3')])
    c.attr(label='process #1')

with g.subgraph(name='cluster_1') as c:
    c.node_attr.update(style='filled')
    c.edges([('b0', 'b1'), ('b1', 'b2'), ('b2', 'b3')])
    c.attr(label='process #2')
    c.attr(color='blue')

g.edge('start', 'a0')
g.edge('start', 'b0')
g.edge('a1', 'b3')
g.edge('b2', 'a3')
g.edge('a3', 'a0')
g.edge('a3', 'end')
g.edge('b3', 'end')

g.node('start', shape='Mdiamond')
g.node('end', shape='Msquare')

g.render("subtree")
PIL.Image.open("subtree.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=299x544 at 0x215ED8BB4A8>

# %%
g = Digraph('G', format='png')
g.attr(compound='true')

with g.subgraph(name='cluster0') as c:
    c.edges(['ab', 'ac', 'bd', 'cd'])

with g.subgraph(name='cluster1') as c:
    c.edges(['eg', 'ef'])

g.edge('b', 'f', lhead='cluster1')
g.edge('d', 'e')
g.edge('c', 'g', ltail='cluster0', lhead='cluster1')
g.edge('c', 'e', ltail='cluster0')
g.edge('d', 'h')

g.render('cluster_edge')
PIL.Image.open('cluster_edge.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=296x485 at 0x215ED8A6470>

# %%
from graphviz import Graph

e = Graph('ER', format='png', engine='neato')

e.attr('node', shape='box')
e.node('course')
e.node('institute')
e.node('student')

e.attr('node', shape='ellipse')
e.node('name0', label='name')
e.node('name1', label='name')
e.node('name2', label='name')
e.node('code')
e.node('grade')
e.node('number')

e.attr('node', shape='diamond', style='filled', color='lightgrey')
e.node('C-I')
e.node('S-C')
e.node('S-I')

e.edge('name0', 'course')
e.edge('code', 'course')
e.edge('course', 'C-I', label='n', len='1.00')
e.edge('C-I', 'institute', label='1', len='1.00')
e.edge('institute', 'name1')
e.edge('institute', 'S-I', label='1', len='1.00')
e.edge('S-I', 'student', label='n', len='1.00')
e.edge('student', 'grade')
e.edge('student', 'name2')
e.edge('student', 'number')
e.edge('student', 'S-C', label='m', len='1.00')
e.edge('S-C', 'course', label='n', len='1.00')

e.attr(label=r'\n\nEntity Relation Diagram\ndrawn by NEATO')
e.attr(fontsize='20')

e.render('er')
PIL.Image.open('er.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=469x582 at 0x215ED8A0080>

# %%
g = Graph('G',format='png', engine='fdp')

g.node('e')

with g.subgraph(name='clusterA') as a:
    a.edge('a', 'b')
    with a.subgraph(name='clusterC') as c:
        c.edge('C', 'D')

with g.subgraph(name='clusterB') as b:
    b.edge('d', 'f')

g.edge('d', 'D')
g.edge('e', 'clusterB')
g.edge('clusterC', 'clusterB')

g.render('fdpclust')
PIL.Image.open('fdpclust.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=477x304 at 0x215ED8BBB70>

# %%
from graphviz import Source
src = Source('digraph "the holy hand grenade" { rankdir=LR; 1 -> 2 -> 3 -> ゴール }')
src.format='png'
src

# %%
f = Digraph('finite_state_machine', filename='fsm.gv')
f.attr(rankdir='LR', size='8,5')

f.attr('node', shape='doublecircle')
f.node('LR_0')
f.node('LR_3')
f.node('LR_4')
f.node('LR_8')

f.attr('node', shape='circle')
f.edge('LR_0', 'LR_2', label='SS(B)')
f.edge('LR_0', 'LR_1', label='SS(S)')
f.edge('LR_1', 'LR_3', label='S($end)')
f.edge('LR_2', 'LR_6', label='SS(b)')
f.edge('LR_2', 'LR_5', label='SS(a)')
f.edge('LR_2', 'LR_4', label='S(A)')
f.edge('LR_5', 'LR_7', label='S(b)')
f.edge('LR_5', 'LR_5', label='S(a)')
f.edge('LR_6', 'LR_6', label='S(b)')
f.edge('LR_6', 'LR_5', label='S(a)')
f.edge('LR_7', 'LR_8', label='S(b)')
f.edge('LR_7', 'LR_5', label='S(a)')
f.edge('LR_8', 'LR_6', label='S(b)')
f.edge('LR_8', 'LR_5', label='S(a)')

f

# %%
u = Digraph('unix', filename='unix.gv')
u.attr(size='6,6')
u.node_attr.update(color='lightblue2', style='filled')

u.edge('5th Edition', '6th Edition')
u.edge('5th Edition', 'PWB 1.0')
u.edge('6th Edition', 'LSX')
u.edge('6th Edition', '1 BSD')
u.edge('6th Edition', 'Mini Unix')
u.edge('6th Edition', 'Wollongong')
u.edge('6th Edition', 'Interdata')
u.edge('Interdata', 'Unix/TS 3.0')
u.edge('Interdata', 'PWB 2.0')
u.edge('Interdata', '7th Edition')
u.edge('7th Edition', '8th Edition')
u.edge('7th Edition', '32V')
u.edge('7th Edition', 'V7M')
u.edge('7th Edition', 'Ultrix-11')
u.edge('7th Edition', 'Xenix')
u.edge('7th Edition', 'UniPlus+')
u.edge('V7M', 'Ultrix-11')
u.edge('8th Edition', '9th Edition')
u.edge('1 BSD', '2 BSD')
u.edge('2 BSD', '2.8 BSD')
u.edge('2.8 BSD', 'Ultrix-11')
u.edge('2.8 BSD', '2.9 BSD')
u.edge('32V', '3 BSD')
u.edge('3 BSD', '4 BSD')
u.edge('4 BSD', '4.1 BSD')
u.edge('4.1 BSD', '4.2 BSD')
u.edge('4.1 BSD', '2.8 BSD')
u.edge('4.1 BSD', '8th Edition')
u.edge('4.2 BSD', '4.3 BSD')
u.edge('4.2 BSD', 'Ultrix-32')
u.edge('PWB 1.0', 'PWB 1.2')
u.edge('PWB 1.0', 'USG 1.0')
u.edge('PWB 1.2', 'PWB 2.0')
u.edge('USG 1.0', 'CB Unix 1')
u.edge('USG 1.0', 'USG 2.0')
u.edge('CB Unix 1', 'CB Unix 2')
u.edge('CB Unix 2', 'CB Unix 3')
u.edge('CB Unix 3', 'Unix/TS++')
u.edge('CB Unix 3', 'PDP-11 Sys V')
u.edge('USG 2.0', 'USG 3.0')
u.edge('USG 3.0', 'Unix/TS 3.0')
u.edge('PWB 2.0', 'Unix/TS 3.0')
u.edge('Unix/TS 1.0', 'Unix/TS 3.0')
u.edge('Unix/TS 3.0', 'TS 4.0')
u.edge('Unix/TS++', 'TS 4.0')
u.edge('CB Unix 3', 'TS 4.0')
u.edge('TS 4.0', 'System V.0')
u.edge('System V.0', 'System V.2')
u.edge('System V.2', 'System V.3')
u

# %%
s = Digraph('structs', node_attr={'shape': 'plaintext'})

s.node('struct1', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0">
  <TR>
    <TD>left</TD>
    <TD PORT="f1">middle</TD>
    <TD PORT="f2">right</TD>
  </TR>
</TABLE>>''')
s.node('struct2', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0">
  <TR>
    <TD PORT="f0">one</TD>
    <TD>two</TD>
  </TR>
</TABLE>>''')
s.node('struct3', '''<
<TABLE BORDER="0" CELLBORDER="1" CELLSPACING="0" CELLPADDING="4">
  <TR>
    <TD ROWSPAN="3">hello<BR/>world</TD>
    <TD COLSPAN="3">b</TD>
    <TD ROWSPAN="3">g</TD>
    <TD ROWSPAN="3">h</TD>
  </TR>
  <TR>
    <TD>c</TD>
    <TD PORT="here">d</TD>
    <TD>e</TD>
  </TR>
  <TR>
    <TD COLSPAN="3">f</TD>
  </TR>
</TABLE>>''')

s.edges([('struct1:f1', 'struct2:f0'), ('struct1:f2', 'struct3:here')])
s

# %%
t = Digraph('TrafficLights', filename='traffic_lights.gv', engine='neato')

t.attr('node', shape='box')
for i in (2, 1):
    t.node('gy%d' % i)
    t.node('yr%d' % i)
    t.node('rg%d' % i)

t.attr('node', shape='circle', fixedsize='true', width='0.9')
for i in (2, 1):
    t.node('green%d' % i)
    t.node('yellow%d' % i)
    t.node('red%d' % i)
    t.node('safe%d' % i)

for i, j in [(2, 1), (1, 2)]:
    t.edge('gy%d' % i, 'yellow%d' % i)
    t.edge('rg%d' % i, 'green%d' % i)
    t.edge('yr%d' % i, 'safe%d' % j)
    t.edge('yr%d' % i, 'red%d' % i)
    t.edge('safe%d' % i, 'rg%d' % i)
    t.edge('green%d' % i, 'gy%d' % i)
    t.edge('yellow%d' % i, 'yr%d' % i)
    t.edge('red%d' % i, 'rg%d' % i)

t.attr(overlap='false')
t.attr(label=r'PetriNet Model TrafficLights\n'
             r'Extracted from ConceptBase and layed out by Graphviz')
t.attr(fontsize='12')
t

# %%
g = Graph('G', filename='g_c_n.gv')
g.attr(bgcolor='purple:pink', label='agraph', fontcolor='white')

with g.subgraph(name='cluster1') as c:
    c.attr(fillcolor='blue:cyan', label='acluster', fontcolor='white',
           style='filled', gradientangle='270')
    c.attr('node', shape='box', fillcolor='red:yellow',
           style='filled', gradientangle='90')
    c.node('anode')
g

# %%
dot = Digraph(comment='The Round Table',format="png")
dot.graph_attr['rankdir'] = 'LR'

def jnode(g, n1,n2):
    g.node(n1,n2, fontname="Meiryo Bold")

jnode(dot,'A', 'アーサー王')
jnode(dot,'B', '賢明なるベディヴィア卿')
jnode(dot,'L', '勇猛なるランスロット卿')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='False')
src = dot.source

# %%
g = pydotplus.graphviz.graph_from_dot_data(src)
g.write_png("iris.png")
PIL.Image.open("iris.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=511x131 at 0x215ED702FD0>

# %%
src
# Out:
# '// The Round Table\ndigraph {\n\tgraph [rankdir=LR]\n\tA [label="アーサー王" fontname="Meiryo Bold"]\n\tB [label="賢明なるベディヴィア卿" fontname="Meiryo Bold"]\n\tL [label="勇猛なるランスロット卿" fontname="Meiryo Bold"]\n\tA -> B\n\tA -> L\n\tB -> L [constraint=False]\n}'

# %%
g.to_string()
# Out:
# 'digraph G {\ngraph [rankdir=LR];\nA [fontname="Meiryo Bold", label="アーサー王"];\nB [fontname="Meiryo Bold", label="賢明なるベディヴィア卿"];\nL [fontname="Meiryo Bold", label="勇猛なるランスロット卿"];\nA -> B;\nA -> L;\nB -> L  [constraint=False];\n}\n'

# %%
for node in g.get_nodes():
    print(node.set_fontname("Meiryo"))
# Out:
# None
# None
# None
# None

# %%
g.to_string()
# Out:
# 'digraph G {\ngraph [fontname=Meiryo, rankdir=LR];\nA [fontname=Meiryo, label="アーサー王"];\nB [fontname=Meiryo, label="賢明なるベディヴィア卿"];\nL [fontname=Meiryo, label="勇猛なるランスロット卿"];\nA -> B;\nA -> L;\nB -> L  [constraint=False];\n}\n'
