# %% [markdown]
# # K-means 法の実験

# %%
import numpy as np
import numpy.matlib
import matplotlib.pyplot as plt
from matplotlib import font_manager
from sklearn.cluster import KMeans
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib　notebook
# %matplotlib　inline

# %%
# ダミーデータの生成　　　　出席点、課題点、試験点
np.random.seed(1)
data1 = np.round(np.random.multivariate_normal([35,28,35],[[3,0.5,1],[0.5,3,0.5],[0.5,0.5,3]],10),1) # すべてよい
data2 = np.round(np.random.multivariate_normal([30,26,25],[[3,0.5,0],[0.5,5,0],[0,0,4]], 20),1) #  出席と課題はよいが試験はいまいち
data3 = np.round(np.random.multivariate_normal([25,20,20],[[5,0,0],[0,5,0],[0,0,4]], 20),1)  #  凡庸
data4 = np.round(np.random.multivariate_normal([35,8,15],[[3,0,0],[0,4,0],[0,0,5]], 10),1)  #  出席だけ
data5 = np.round(np.random.multivariate_normal([8,8,8],[[2,1,1],[1,3,1],[1,1,2]], 10),1) # ダメダメ
data = np.r_[data1,data2,data3,data4,data5]
rank = np.r_[np.array(['A']*10),np.array(['B']*20),np.array(['C']*20),np.array(['D']*10),np.array(['E']*10)]
df = pd.DataFrame(data,columns=['Shusseki','Kadai','Siken'])
df['Rank']=rank
df= df.reindex(np.random.permutation(df.index)).reset_index(drop=True)
df.head(10) #  頭から 10 個だけ表示
# Out:
#    Shusseki  Kadai  Siken Rank
# 0      36.8    3.1   14.3    D
# 1      34.8    8.9   19.9    D
# 2      31.9   27.7   25.6    B
# 3      25.9   18.6   20.2    C
# 4      30.6   26.2   26.8    B
# 5      26.3   20.9   17.8    C
# 6      28.9   28.0   24.6    B
# 7      33.3    7.0   12.5    D
# 8      24.6   21.9   18.8    C
# 9      33.9   28.9   36.3    A

# %% [markdown]
# # ２次元散布図のプロット

# %%
# 新規のウィンドウを描画
fig = plt.figure(figsize=(8,6))
# サブプロットを追加
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
ax1.hist(df['Siken'],bins=20,color='k',alpha=0.3)
ax2.scatter(df['Shusseki'],df['Siken'])
ax2.set_xlabel("Shusseki")
ax2.set_ylabel("Siken")
ax3.scatter(df['Shusseki'],df['Kadai'])
ax3.set_xlabel("Shusseki")
ax3.set_ylabel("Kadai")
ax4.scatter(df['Kadai'],df['Siken'])
ax4.set_xlabel("Kadai")
ax4.set_ylabel("Siken")
plt.show()
plt.savefig("image.png")

# %%
dx,dy,dz,rk = np.array(df['Shusseki']),np.array(df['Kadai']), np.array(df['Siken']),np.array(df['Rank'])
fig = plt.figure()
ax = Axes3D(fig)
ax.set_xlabel("Shusseki")
ax.set_ylabel("Kadai")
ax.set_zlabel("Shiken")
ax.scatter3D(dx[df['Rank']=='A'], dy[df['Rank']=='A'], dz[df['Rank']=='A'], c="green")
ax.scatter3D(dx[df['Rank']=='B'], dy[df['Rank']=='B'], dz[df['Rank']=='B'], c="blue")
ax.scatter3D(dx[df['Rank']=='C'], dy[df['Rank']=='C'], dz[df['Rank']=='C'], c="orange")
ax.scatter3D(dx[df['Rank']=='D'], dy[df['Rank']=='D'], dz[df['Rank']=='D'], c="purple")
ax.scatter3D(dx[df['Rank']=='E'], dy[df['Rank']=='E'], dz[df['Rank']=='E'], c="red")
plt.show()

# %% [markdown]
# # 数値データ部分だけを抽出¶

# %%
data = df.T[0:3].T
data.head()
# Out:
#   Shusseki Kadai Siken
# 0     36.8   3.1  14.3
# 1     34.8   8.9  19.9
# 2     31.9  27.7  25.6
# 3     25.9  18.6  20.2
# 4     30.6  26.2  26.8

# %% [markdown]
# # K-means　法によるクラスタリング

# %%
def d(n,itr):
    global result
    km = KMeans(n_clusters=n,init='random',n_init=1,max_iter=itr,random_state=1)
    result = km.fit(data)
    fig = plt.figure()
    ax = Axes3D(fig)
    # 
    ax.set_xlabel("Shusseki")
    ax.set_ylabel("Kadai")
    ax.set_zlabel("Shiken")
    
    print(np.round([km.cluster_centers_[:,0],km.cluster_centers_[:,1],km.cluster_centers_[:,2]],2))
    ax.scatter3D(km.cluster_centers_[:,0],km.cluster_centers_[:,1],km.cluster_centers_[:,2],marker='X',c='black')
    ax.scatter3D(dx[result.labels_==0.0], dy[result.labels_==0.0], dz[result.labels_==0.0], c="green")
    ax.scatter3D(dx[result.labels_==1.0], dy[result.labels_==1.0], dz[result.labels_==1.0], c="blue")
    if n > 2:
        ax.scatter3D(dx[result.labels_==2.0], dy[result.labels_==2.0], dz[result.labels_==2.0],c="orange")
    if n > 3:
        ax.scatter3D(dx[result.labels_==3.0], dy[result.labels_==3.0], dz[result.labels_==3.0],c="purple")
    if n > 4:
        ax.scatter3D(dx[result.labels_==4.0], dy[result.labels_==4.0], dz[result.labels_==4.0],c="yellow")
    if n > 5:
        ax.scatter3D(dx[result.labels_==5.0], dy[result.labels_==5.0], dz[result.labels_==5.0],c="red")   
    plt.show()
    return result

# %% [markdown]
# ## 2ランクに分けるなら

# %%
d(2,20)
# Out:
# [[ 32.12  23.35]
#  [ 26.06  14.2 ]
#  [ 28.44  15.93]]
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=20,
#     n_clusters=2, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=1, tol=0.0001, verbose=0)

# %% [markdown]
# ## 3クラスタに分類

# %%
d(3,100)
# Out:
# [[ 28.05  19.99  35.24]
#  [ 22.19   7.52  27.67]
#  [ 22.31  11.33  33.79]]
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=3, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=1, tol=0.0001, verbose=0)

# %% [markdown]
# ## ４クラスタに分類

# %%
d(4,100)
# Out:
# [[ 27.71  35.14  35.24   7.79]
#  [ 22.76   7.84  27.67   7.89]
#  [ 22.51  15.8   33.79   8.29]]
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=1, tol=0.0001, verbose=0)

# %% [markdown]
# # ５クラスタに分類

# %%
d(5,100)
# Out:
# [[ 25.39  35.14  30.62   7.79  35.34]
#  [ 20.65   7.84  25.36   7.89  27.68]
#  [ 19.92  15.8   25.66   8.29  34.37]]
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=5, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=1, tol=0.0001, verbose=0)

#
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=5, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=1, tol=0.0001, verbose=0)

# %% [markdown]
# # 設定したランクと生成されたクラスタの比較

# %%
df2 = df.copy()
df2['AutoLabel'] = result.labels_
df2
# Out:
#     Shusseki  Kadai  Siken Rank  AutoLabel
# 0       36.8    3.1   14.3    D          1
# 1       34.8    8.9   19.9    D          1
# 2       31.9   27.7   25.6    B          2
# 3       25.9   18.6   20.2    C          0
# 4       30.6   26.2   26.8    B          2
# 5       26.3   20.9   17.8    C          0
# 6       28.9   28.0   24.6    B          2
# 7       33.3    7.0   12.5    D          1
# 8       24.6   21.9   18.8    C          0
# 9       33.9   28.9   36.3    A          4
# 10      33.1   23.8   25.4    B          2
# 11      30.3   21.2   24.4    B          2
# 12      35.0    7.8   14.7    D          1
# 13      38.4   26.2   34.1    A          4
# 14      26.2   17.2   21.6    C          0
# 15       7.0    6.2    6.1    E          3
# 16      25.3   21.2   20.2    C          0
# 17      30.5   24.1   27.5    B          2
# 18      35.4   10.0   14.6    D          1
# 19      25.8   23.6   17.6    C          0
# 20      35.9    7.4   15.6    D          1
# 21       6.2    4.2    7.2    E          3
# 22      20.8   24.4   22.5    C          0
# 23      37.2   29.4   35.4    A          4
# 24      23.3   19.9   22.5    C          0
# 25      35.4   29.4   36.6    A          4
# 26      28.5   24.7   24.2    B          2
# 27      39.3   27.9   34.6    A          4
# 28      29.8   26.6   26.5    B          2
# 29      29.2   25.4   22.7    B          2
# ..       ...    ...    ...  ...        ...
# 40       9.5   11.5    7.1    E          3
# 41      32.1   26.4   25.2    B          2
# 42      27.5   16.4   20.8    C          0
# 43      30.6   26.1   26.2    B          2
# 44      29.7   25.4   26.0    B          2
# 45      33.6   25.6   34.6    A          4
# 46      25.4   22.7   19.2    C          0
# 47      34.6   13.1   17.0    D          1
# 48       6.8   10.3    9.6    E          3
# 49      29.0   26.7   25.2    B          2
# 50       7.4    6.9    7.8    E          3
# 51      31.3   25.2   26.2    B          2
# 52      25.1   19.4   17.3    C          0
# 53       8.1    5.9    7.5    E          3
# 54      24.0   21.6   22.4    C          0
# 55       5.4    7.3    8.2    E          3
# 56      33.3   27.1   32.0    A          4
# 57      22.1   20.8   19.9    C          0
# 58      25.5   21.4   21.4    C          0
# 59      30.6   25.4   25.4    B          2
# 60      25.1   21.8   19.6    C          0
# 61      25.1   19.2   18.8    C          0
# 62      34.4    9.4   14.4    D          1
# 63       8.5    7.1    9.1    E          3
# 64      26.7   20.4   18.1    C          0
# 65      29.7   24.3   28.4    B          2
# 66      36.5   27.1   34.2    A          4
# 67      34.2   27.6   28.0    B          2
# 68      29.5   24.1   23.7    B          2
# 69      26.9   20.7   18.3    C          0
#
# [70 rows x 5 columns]
