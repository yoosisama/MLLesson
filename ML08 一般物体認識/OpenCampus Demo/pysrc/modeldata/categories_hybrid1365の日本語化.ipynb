# %%
# Google 翻訳サービスを使う　ーーーーーーーーーーーーーーーーーーー
import requests
import re
 
url = 'https://translate.google.com/?hl=ja#en/ja/'
 
def translate(estring):
    r = requests.get(url, params={'q': estring})
 
    pattern = "TRANSLATED_TEXT=\'(.*?)\'"
    jstring = re.search(pattern, r.text).group(1)
 
    return jstring
# Google 翻訳サービスを使う　ーーーーーーーーーーーーーーーーーーー

import json
f = open('imagenet_class_index.json','r')
fj = json.load(f)

# %%
fj[5]
# Out:
# {'en': 'electric_ray', 'ja': 'シビレエイ', 'num': 'n01496331'}

# %%
fj[5]['ja']
# Out:
# 'シビレエイ'

# %%
f1 = open('categories_hybrid1365.txt','r')
f2 = open('temp.txt', 'w')
for l in range(1000):
    _ = f1.readline()
    f2.write(fj[l]['ja']+'\n')
for l in range(365):
    string = f1.readline()[3:-1]
    string,num = string.rsplit(' ',1)
    f2.write(translate(string.replace('_',' '))+'\n')
f1.close()
f2.close()
f.close()

# %% [markdown]
# ## 手作業で修正
# ```
# テンチ
# 金魚
# ホホジロザメ
# イタチザメ
# ハンマーヘッド
# シビレエイ
# アカエイ
# おんどり
# めんどり
# ダチョウ
# アトリ（鳥類）
# ゴシキヒワ（鳥類）
# ハウスフィンチ（鳥類）
# ユキヒメドリ
# インディゴホオジロ
# コマツグミ、ロビン
# ヒヨドリ、ブルブル
# カケス
# カササギ
# 四十雀
# 水クロウタドリ
# 凧
# 白頭ワシ
# ハゲワシ
# カラフトフクロウ
# ファイアサラマンダー
# スベイモリ
# イモリ
# トラフサンショウウオ
# アホロートル
# ウシガエル
# アマガエル
# 有尾カエル、アスカフス
# アカウミガメ
# オサガメ
# ドロガメ
# ヌマガメ、キスイガメ
# ハコガメ
# 縞ヤモリ
# イグアナ
# アメリカンカメレオン
# ウィップテール・リザード
# アガマトカゲ
# フリルトカゲ
# アリゲータートカゲ
# アメリカドクトカゲ
# ミドリカナヘビ
# アフリカン・カメレオン
# コモドドラゴン
# ナイルワニ、クロコダイル
# アリゲータ
# トリケラトプス
# ミミズヘビ
# リングネックスネーク
# クサリヘビ
# グラススネーク（ヨーロッパヤマカガシ）
# キングスネーク
# ガータースネーク
# ミズヘビ
# ツルヘビ
# ナイトスネーク
# ボア・コンストリクター
# ロックパイソン
# インドコブラ
# グリーンマンバ
# ウミヘビ
# ツノクサリヘビ
# ダイヤモンドバック、ダイヤガラガラヘビ
# サイドワインダー
# 三葉虫
# ザトウムシ
# サソリ
# キマダラコガネグモ
# オニグモ
# 庭オニグモ
# クロゴケグモ
# タランチュラ
# コモリグモ
# ダニ
# 百足
# クロライチョウ
# 雷鳥
# エリマキライチョウ
# 草原ライチョウ
# 孔雀
# ウズラ
# ヤマウズラ
# ヨウム、灰インコ
# コンゴウインコ
# キバタン(オウム)
# インコ
# バンケン（カッコウ）
# 蜂食べる人
# サイチョウ
# ハチドリ
# キリハシ
# オオハシ
# ドレイク（オス鴨）
# ウミアイサ（カモ）
# ガチョウ
# 黒鳥
# 牙の生えた象
# ハリモグラ
# カモノハシ
# ワラビー
# コアラ
# ウォンバット
# クラゲ
# イソギンチャク
# 脳サンゴ、キクメイシ
# 扁形動物
# 線虫
# 巻き貝
# カタツムリ
# ナメクジ
# ウミウシ
# ヒザラガイ
# オウムガイ
# アメリカイチョウガニ
# 岩カニ
# シオマネキ
# タラバガニ
# アメリカンロブスター
# 伊勢エビ
# ザリガニ
# ヤドカリ
# ワラジムシ、フナムシ
# コウノトリ
# ナベコウ
# ヘラサギ
# フラミンゴ
# スミレサギ
# アメリカン白鷺
# サンカノゴイ・ヨシゴイ
# ツル
# ツルモドキ
# ヨーロピアン水鳥
# アメリカオオバン
# ノガン
# キョウジョシギ
# ハマシギ
# アカアシシギ
# オオハシシギ
# ミヤコドリ
# ペリカン
# キングペンギン
# アルバトロス
# コククジラ
# シャチ
# ジュゴン
# アシカ
# チワワ
# 狆（チン）
# マルチーズ
# ペキニーズ
# シーズー
# ブレナムスパニエル
# パピヨン
# トイテリア
# ローデシアン・リッジバック
# アフガンハウンド
# バセット犬
# ビーグル
# ブラッドハウンド
# ブルーティック
# ブラック・アンド・タン・クーンハウンド
# ウォーカーハウンド
# イングリッシュフォックスハウンド
# レッドボーン
# ボルゾイ
# アイリッシュ・ウルフハウンド
# イタリアングレーハウンド
# ウィペット
# イビサハウンド
# ノルウェーエルクハウンド
# オッターハウンド
# サルーキ
# スコティッシュ・ディアハウンド
# ワイマラナー
# スタフォードシャーブルテリア
# アメリカン・スタッフォードシャー・テリア
# ベドリントンテリア
# ボーダーテリア
# ケリーブルーテリア
# アイリッシュテリア
# ノーフォークテリア
# ノーリッチ・テリア
# ヨークシャーテリア
# ワイヤーヘアー・フォックステリア
# レークランドテリア
# シーリーハムテリア
# エアデール
# ケルンテリア
# オーストラリアテリア
# ダンディディンモントテリア
# ボストンブル
# ミニチュアシュナウザー
# ジャイアントシュナウザー
# スタンダードシュナウザー
# スコッチテリア
# チベタンテリア
# シルキーテリア
# ソフトコーテッド・ウィートン・テリア
# ウェストハイランドホワイトテリア
# ラサ
# フラットコーテッド・レトリーバー
# カーリーコーティングされたレトリーバー
# ゴールデンレトリバー
# ラブラドル・レトリーバー
# チェサピーク・ベイ・レトリーバー
# ジャーマン・ショートヘア・ポインタ
# ビズラ
# イングリッシュセッター
# アイリッシュセッター
# ゴードンセッター
# ブリタニースパニエル
# クランバー
# イングリッシュスプリンガー
# ウェルシュスプリンガースパニエル
# コッカースパニエル
# サセックススパニエル
# アイルランドのウォータースパニエル
# クバース犬
# スキッパーキー
# ベルジアン・シェパード・ドッグ・グローネンダール
# マリノア
# ブリアール
# ケルピー
# コモンドール
# オールドイングリッシュシープドッグ
# シェトランドシープドッグ
# コリー
# ボーダーコリー
# ブーヴィエ・デ・フランドル
# ロットワイラー
# ジャーマンシェパード
# ドーベルマン犬
# ミニチュアピンシャー
# グレータースイスマウンテンドッグ
# バーネーズマウンテンドッグ
# アッペンツェル
# エントレブッシャー
# ボクサー
# ブルマスチフ
# チベットマスチフ
# フレンチブルドッグ
# グレートデーン
# セントバーナード
# エスキモー犬
# マラミュート
# シベリアンハスキー
# ダルメシアン
# アーフェンピンシャー
# バセンジー
# パグ
# レオンバーグ
# ニューファンドランド（犬）
# グレートピレニーズ
# サモエド
# ポメラニアン
# チャウチャウ
# キースホンド
# ブラバンソングリフォン
# ペンブローク
# カーディガン
# トイプードル
# ミニチュアプードル
# スタンダードプードル
# メキシカン・ヘアーレス
# シンリンオオカミ
# ホワイトオオカミ
# レッドウルフ
# コヨーテ
# ディンゴ
# ドール
# リカオン
# ハイエナ
# アカギツネ
# キットキツネ
# ホッキョクギツネ
# 灰色キツネ
# タビー猫
# 虎猫
# ペルシャ猫
# シャム猫
# エジプト猫
# クーガー
# オオヤマネコ
# ヒョウ
# ユキヒョウ
# ジャガー
# ライオン
# 虎
# チーター
# ヒグマ
# アメリカクロクマ
# ホッキョクグマ
# ナマケグマ
# マングース
# ミーアキャット
# ハンミョウ
# てんとう虫
# グランドビートル
# カミキリムシ
# ハムシ
# フンコロガシ
# サイハムシ
# ゾウムシ
# ハエ
# 蜂
# 蟻
# バッタ
# コオロギ
# ナナフシ
# ゴキブリ
# カマキリ
# 蝉
# ヨコバイ
# クサカゲロウ
# トンボ
# イトトンボ
# タテハ蝶
# ジャノメチョウ
# オオカバマダラ
# モンシロチョウ
# 硫黄蝶
# シジミチョウ
# ヒトデ
# うに
# ナマコ
# ワタオウサギ
# 野ウサギ
# アンゴラ
# ハムスター
# ヤマアラシ
# キツネリス
# マーモット
# ビーバー
# モルモット
# 栗色（のウマ）
# シマウマ
# 豚
# イノシシ
# イボイノシシ
# カバ
# 雄牛
# 水牛
# バイソン
# ラム
# ビッグホーン
# アイベックス
# ハーテビースト
# インパラ
# ガゼル
# アラビアラクダ
# ラマ
# イタチ
# ミンク
# ケナガイタチ
# クロアシイタチ
# カワウソ
# スカンク
# 狸
# アルマジロ
# ミユビナマケモノ
# オランウータン
# ゴリラ
# チンパンジー
# テナガザル
# フクロテナガザル
# オナガザル
# パタスモンキー
# ヒヒ
# マカク
# ヤセザル
# コロブス猿
# テングザル
# マーモセット
# オマキザル
# ホエザル
# ティティ
# クモザル
# リスザル
# マダガスカル猫
# インドリ（マダガスカルキツネザル）
# インドゾウ
# アフリカゾウ
# レッサーパンダ
# ジャイアントパンダ
# バラクータ
# ウナギ
# ギンザケ
# ロック･ビューティー
# クマノミ
# チョウザメ
# ロングノーズガー
# ミノカサゴ
# フグ
# そろばん
# アバヤ（イスラム民族衣装）
# アカデミックガウン
# アコーディオン
# アコースティックギター
# 空母
# 旅客機
# 飛行船
# 祭壇
# 救急車
# 両生類
# アナログ時計
# 養蜂場
# エプロン
# ごみ入れ
# アサルトライフル
# バックパック
# ベーカリー
# 平均台
# バルーン
# ボールペン
# バンドエイド
# バンジョー
# バニスター
# バーベル
# 理髪店の椅子
# 理髪店
# 納屋
# バロメーター
# バレル
# バロー,手押し車
# 野球
# バスケットボール
# バシネット,ほろ付き揺りかご
# ファゴット,バスーン（楽器）
# 水泳帽
# バスタオル
# バスタブ
# ビーチワゴン
# ビーコン,航路標識
# ビーカー
# シャコー（筒型軍帽）
# ビール瓶
# ビールグラス
# ベルコート,鐘尖塔
# ビブ,よだれかけ
# 自転車
# ビキニ
# バインダー
# 双眼鏡
# 巣箱
# ボートハウス
# ボブスレー
# ループタイ
# ボンネット
# 本棚
# 書店
# 瓶のキャップ
# 弓
# ちょうネクタイ
# 真鍮
# ブラジャー
# 防波堤
# 胸当て
# ほうき
# バケツ
# バックル
# 防弾チョッキ
# 新幹線
# 精肉店
# タクシー
# 大釜
# キャンドル
# 大砲
# カヌー
# 缶切り
# カーディガン
# 車のミラー
# 回転木馬
# 大工のキット
# カートン
# 車のホイール
# 現金自動預け払い機
# カセット
# カセット・プレーヤー
# 城
# カタマラン,双胴船
# CDプレーヤー
# チェロ
# スマートフォン
# 鎖
# チェーンリンクフェンス
# チェーンメール,鎖帷子
# チェーンソー
# チェスト,整理箪笥（蓋付きの箱タイプ）
# シフォニア,整理箪笥（引き出しタイプ）
# チャイム
# 中国キャビネット
# クリスマスの靴下
# 教会
# 映画
# 肉切り包丁
# 崖の住居
# マント
# クロッグ, 下駄（木星の履物）
# カクテルシェーカー
# コーヒーマグ
# コーヒーポット
# コイル
# ダイヤル錠
# コンピュータのキーボード
# 製菓屋
# コンテナ船
# コンバーチブル
# コークスクリュー
# コルネット
# カウボーイブーツ
# カウボーイハット
# クレードル
# クレーン
# クラッシュヘルメット
# 木箱
# ベビーベッド
# クロークポット
# クロケットボール
# 松葉杖
# 胸当て
# ダム
# 机
# デスクトップコンピューター
# ダイヤル電話
# おむつ
# デジタル時計
# デジタル腕時計
# ダイニングテーブル
#  ふきん
# 食器洗い機
# ディスクブレーキ
# （船の）ドック
# 犬ぞり
# ドーム
# 玄関マット
# 掘削基地
# ドラム
# ドラムスティック
# ダンベル
# ダッチオーブン
# 扇風機
# エレキギター
# 電気機関車
# 娯楽施設
# 封筒
# エスプレッソマシーン
# フェースパウダー
# フェザーボア
# ファイル
# 消防艇
# 消防車
# ファイアースクリーン
# 旗竿
# フルート
# 折り畳み式椅子
# フットボールヘルメット
# フォークリフト
# 噴水
# 万年筆
# 四柱式ベッド
# 貨車
# フレンチホルン
# フライパン
# 毛皮のコート
# ごみ収集車
# ガスマスク
# ガソリンポンプ
# ゴブレット
# ゴーカート
# ゴルフボール
# ゴルフカート
# ゴンドラ
# ゴング
# ガウン
# グランドピアノ
# 温室
# グリル
# 食料品店
# ギロチン
# ヘアスライド
# ヘアスプレー
# ハーフトラック,半装軌車
# ハンマー
# 手提げカゴ
# ハンドブロワー
# タブレット
# ハンカチ
# ハードディスク
# ハーモニカ
# ハープ
# ハーベスタ
# 斧
# ホルスター
# ホームシアター
# ハニカム
# フック
# フープスカート
# 鉄棒
# 馬車
# 砂時計
# アイフォーン
# 鉄
# ジャックオーランタン
# ジーンズ
# ジープ
# ジャージー
# ジグソーパズル
# 人力車
# ジョイスティック
# 着物
# 膝パッド
# 結び目
# 白衣
# ひしゃく
# ランプのかさ
# ノートパソコン
# 芝刈り機
# レンズキャップ
# レターオープナー
# ライブラリ
# 救命ボート
# ライター
# リムジン
# ライナー
# 口紅
# ローファー
# ローション
# スピーカー
# ルーペ
# 製材所
# 磁気コンパス
# 郵袋
# メールボックス
# レオタード
# ワンピースの水着
# マンホールの蓋
# マラカス
# マリンバ
# マスク
# マッチ棒
# メイポール
# 迷路
# 計量カップ
# 薬箱
# 巨石
# マイク
# マイクロ波
# 軍服
# ミルク缶
# ミニバス
# ミニスカート
# ミニバン
# ミサイル
# ミトン
# ミキシングボウル
# 移動住宅
# モデルT（クラシックカー）
# モデム
# 修道院
# モニター
# モペット
# 乳鉢
# モルタルボード
# モスク
# 蚊帳
# スクーター
# マウンテンバイク
# 山のテント
# マウス
# ネズミ捕り
# 引っ越しトラック
# 銃口
# ネイル
# ネックブレース（頚椎コルセット）
# ネックレス
# 乳首
# ノート
# オベリスク
# オーボエ
# オカリナ
# オドメーター
# オイルフィルター
# オルガン
# オシロスコープ
# オーバースカート
# 牛車
# 酸素マスク
# パケット
# パドル
# パドルホイール
# 南京錠
# 絵筆
# パジャマ
# 宮殿
# パンパイプ
# ペーパータオル
# パラシュート
# 平行棒
# 公園のベンチ
# パーキングメーター
# 乗用車
# パティオ
# 有料電話
# 台座
# 筆箱
# 鉛筆削り
# 香水
# ペトリ皿
# コピー機
# ピック
# スパイク付き鉄かぶと
# 杭柵
# ピックアップトラック
# 桟橋
# 貯金箱
# 錠剤瓶
# 枕
# ピンポン球
# 風車
# 海賊
# ピッチャー
# 飛行機
# プラネタリウム
# ビニール袋
# 皿立て
# すき
# プランジャー、ラバーカップ（すっぽん）
# ポラロイドカメラ
# ポール
# 警察車
# ポンチョ
# ビリヤード台
# ペット・ボトル
# ポット
# ろくろ
# パワードリル
# 礼拝用敷物
# プリンタ
# 刑務所
# 発射体
# プロジェクター
# パック
# サンドバッグ
# 財布
# クイル,羽ペン
# キルト
# レーサー
# ラケット
# ラジエーター
# 無線
# 電波望遠鏡
# 天水桶
# RV車
# リール
# レフレックスカメラ
# 冷蔵庫
# リモコン
# レストラン
# リボルバー
# ライフル
# ロッキングチェア
# 焼肉料理店
# 消しゴム
# ラグビーボール
# 定規,ものさし
# ランニングシューズ
# 金庫
# 安全ピン
# 塩の入れ物
# サンダル
# サロン
# サックス
# 鞘
# 体重計
# スクールバス
# スクーナー,帆船
# スコアボード
# 画面
# スクリュー
# ドライバー
# シートベルト
# ミシン
# シールド
# 靴屋
# 障子
# 買い物かご
# ショッピングカート
# シャベル
# シャワーキャップ
# シャワーカーテン
# スキー
# スキーマスク
# 寝袋
# 計算尺
# 引き戸
# スロット
# スノーケル
# スノーモービル
# 除雪機
# ソープディスペンサー
# サッカーボール
# 靴下
# 太陽の皿
# ソンブレロ（帽子）
# スープ皿
# スペースキー
# スペースヒーター（暖房器具）
# スペースシャトル
# へら
# スピードボート
# クモの巣
# スピンドル
# スポーツカー
# スポットライト
# ステージ
# 蒸気機関車
# 鋼アーチ橋
# スチールドラム
# 聴診器
# ストール
# 石垣
# ストップウォッチ
# レンジ
# ストレーナー
# 路面電車
# ストレッチャー
# スタジオソファ
# 仏舎利塔
# 潜水艦
# スーツ
# 日時計
# 虫眼鏡
# サングラス
# 日焼け止め剤
# つり橋
# 綿棒
# トレーナー
# 海パン
# スイング
# スイッチ
# 注射器
# 電気スタンド
# タンク
# テーププレーヤー
# ティーポット
# テディベア
# テレビ
# テニスボール
# 茅葺屋根
# 劇場のカーテン
# 指ぬき
# 脱穀機
# 王座
# 瓦屋根
# トースター
# タバコ屋
# 便座
# トーチ
# トーテムポール
# レッカー車
# 玩具屋
# トラクター
# トレーラートラック
# トレイ
# トレンチコート
# 三輪車
# 三胴船
# 三脚
# 凱旋門
# トロリーバス
# トロンボーン
# バスタブ
# 回転ドア
# タイプライターのキーボード
# 傘
# 一輪車
# アップライトピアノ
# 掃除機
# 花瓶
# アーチ天井
# ベルベット
# 自動販売機
# 祭服
# 高架橋
# バイオリン
# バレーボール
# ワッフル焼き型
# 壁時計
# 財布
# ワードローブ
# 戦闘機
# 洗面器
# ワッシャー,自動洗濯機
# 水筒
# 水差し
# 給水塔
# ウイスキージャグ
# ホイッスル
# かつら
# 窓網戸
# ブラインド
# ウィンザーネクタイ
# ワインボトル
# 翼
# 中華鍋
# 木製スプーン
# ウール
# ワームフェンス
# 難破船
# ヨール, 小型帆船
# パオ
# ウェブサイト
# コミックブック
# クロスワードパズル
# 道路標識
# 交通信号灯
# ブックカバー
# メニュー
# プレート
# グアカモーレ（メキシコ料理）
# コンソメ
# ホットポット（鍋料理）
# パフェ
# アイスクリーム
# アイスキャンディー
# フランスパン
# ベーグル
# プレッツェル
# チーズバーガー
# ホットドッグ
# マッシュポテト
# キャベツ
# ブロッコリー
# カリフラワー
# ズッキーニ
# そうめんかぼちゃ
# ドングリかぼちゃ
# カボチャ
# キュウリ
# アーティチョーク（あざみの実、食材）
# ピーマン
# カルドン
# キノコ
# リンゴ
# イチゴ
# オレンジ
# レモン
# イチジク
# パイナップル
# バナナ
# パラミツ
# カスタードアップル
# ザクロ
# 干し草
# カルボナーラ
# チョコレートソース
# パン生地
# ミートローフ
# ピザ
# ポットパイ
# ブリトー
# 赤ワイン
# エスプレッソ
# カップ
# エッグノッグ
# アルプス,高山
# バブル
# 崖
# サンゴ礁
# 間欠泉
# 湖畔
# 岬
# 砂州
# 海岸
# 谷
# 火山
# 野球選手
# 新郎
# スキューバダイバー
# 菜種
# デイジー
# 蘭
# トウモロコシ
# ドングリ
# ヒップ
# トチノキ
# サンゴ菌
# ハラタケ
# シャグマアミガサタケ
# スッポンタケ
# ハラタケ
# 舞茸
# きのこ
# トウモロコシの穂（実）
# トイレットペーパー
# 飛行場
# 飛行機のキャビン
# 空港ターミナル
# アルコーブ
# 路地
# 円形劇場
# アミューズメント施設
# 遊園地
# アパート/アウトドア
# 水族館
# 水道
# アーケード
# アーチ
# 考古学的発掘
# アーカイブ
# アリーナ/ホッケー
# アリーナ/パフォーマンス
# アリーナ/ロデオ
# 軍基地
# アートギャラリー
# 美術学校
# アートスタジオ
# アーティストロフト
# 組み立てライン
# 陸上競技場
# アトリウム/パブリック
# 屋根裏
# 講堂
# 自動車工場
# 自動車ショールーム
# 悪路
# ベーカリー/ショップ
# バルコニー/エクステリア
# バルコニー/インテリア
# ボールピット,ボールプール
# 舞踏場,ダンスホール
# 竹林
# 銀行の金庫
# 宴会場
# バー
# 農家の納屋
# 納屋の扉
# 野球場
# 地下
# バスケットボールコート/屋内
# バスルーム
# バザール/屋内
# バザール/アウトドア
# ビーチ
# 海の家
# ビューティーサロン
# 寝室
# 寝室
# ビアガーデン
# ビヤホール
# 寝台
# 生物学研究室
# 遊歩道
# ボートデッキ
# ボートハウス
# 書店
# ブース/屋内
# 植物園
# 出窓/屋内
# ボーリング場
# ボクシングのリング
# ブリッジ
# 建物のファサード
# 闘牛
# 埋葬室
# バスのインテリア
# バスステーション/屋内
# 肉屋
# バート
# キャビン/アウトドア
# カフェテリア
# キャンプサイト
# キャンパス
# 運河/自然
# 運河/都市
# お菓子屋
# キャニオン
# 車内
# カルーセル（回転木馬）
# 城
# カタコンベ
# 墓地
# シャレー,バンガロー
# 化学ラボ
# チャイルドルーム
# 教会/屋内
# 教会/野外
# 教室
# クリーンルーム
# 崖
# クローゼット
# 洋服店
# 海岸
# コックピット
# コーヒーショップ
# コンピューター室
# 会議センター
# 会議室
# 建設現場
# コーンフィールド
# コラール,柵囲い
# 廊下
# コテージ
# 裁判所
# 中庭
# クリーク（小径）
# クレバス
# 横断歩道
# ダム
# デリカテッセン
# デパート
# 砂漠/砂
# 砂漠/植生
# 砂漠の道
# ダイナー,簡易食堂/アウトドア
# 食堂
# ダイニングルーム
# ディスコ
# 出入り口/屋外
# 寮の部屋
# ダウンタウン
# 脱衣室
# 車道
# 薬局
# エレベーター/ドア
# エレベーターロビー
# エレベータシャフト
# 大使館
# エンジンルーム
# エントランス・ホール
# エスカレーター/屋内
# 発掘
# ファブリックストア
# ファーム
# ファストフードレストラン
# フィールド/栽培
# フィールド/野生
# フィールドロード
# 火災逃避
# 消防署
# 釣り糸
# フリーマーケット/屋内
# 花屋ショップ/屋内
# フードコート
# サッカー場
# 森林/広葉樹
# 森林の道
# 林道
# フォーマルな庭
# 噴水
# ギャレー, 厨房
# ガレージ/屋内
# ガレージ/アウトドア
# ガソリンスタンド
# ガゼボ,あずま屋/外装
# 雑貨店/屋内
# 雑貨店舗/屋外
# ギフトショップ
# 氷河
# ゴルフ場
# 温室/屋内
# 温室/屋外
# グロット,ほら穴,岩屋
# 体育館/屋内
# ハンガー（格納庫）/屋内
# ハンガー（格納庫）/アウトドア
# 港
# ハードウェアストア
# ヘイフィールド,干し草畑
# ヘリポート
# ハイウェイ
# ホームオフィス
# ホームシアター
# 病院
# 病室
# 温泉
# ホテル/アウトドア
# ホテルの部屋
# 家
# 狩猟用ロッジ/アウトドア
# アイスクリーム屋
# 氷原
# 氷棚
# アイススケートリンク/屋内
# アイススケートリンク/アウトドア
# 氷山,流氷
# イグルー, イヌイットの住居
# 工業地帯
# 宿屋/アウトドア
# 島
# ジャグジー/屋内
# 刑務所
# 日本庭園
# ジュエリーショップ
# 廃品置き場
# カスバ,アフリカ北部の旧市街
# 犬小屋/アウトドア
# 幼稚園教室
# キッチン
# ラグーン
# 湖/自然
# 埋立地
# 着陸デッキ
# コインランドリー
# 芝生
# 講義室
# 立法室
# 図書館/屋内
# ライブラリー/アウトドア
# 灯台
# リビングルーム
# 発送センター
# ロビー
# ロック室
# ロッカールーム
# 大邸宅
# 製造された家
# 市場/屋内
# マーケット/アウトドア
# 沼地
# 武道のジム
# 霊廟
# メディナ,イスラムの聖地
# メザニン,舞台下
# 堀/水
# モスク/アウトドア
# モーテル
# 山
# 山道
# 雪山
# 映画館/屋内
# 博物館/室内
# 博物館/アウトドア
# 音楽スタジオ
# 自然史博物館
# 保育園
# 老人ホーム
# オイスターハウス, ホップの乾燥小屋
# 海洋
# 事務所
# オフィスビル
# オフィスキュービクル,パーティションに区切られた様子
# オイルリグ,油田
# 手術室
# オーチャード, 果樹園
# オーケストラ席
# パゴダ, ヒンズー教の多層塔
# 宮殿
# パントリー,食品貯蔵庫
# パーク,公園
# ガレージ/屋内
# ガレージ/屋外
# 駐車場
# 牧草地
# パティオ
# パビリオン
# ペットショップ
# 薬局
# 公衆電話ボックス
# 物理実験室
# ピクニックエリア
# 桟橋
# ピザ屋
# 遊び場
# プレイルーム
# 広場
# 池
# ポーチ
# プロムナード
# パブ/室内
# 競馬場
# 軌道
# ラフト,浮き桟橋,いかだ
# 鉄道線路
# 熱帯雨林
# 受付
# レクリエーションルーム
# 修理店
# 住宅地周辺
# レストラン
# レストランキッチン
# レストランパティオ
# 田んぼ
# 川
# ロックアーチ
# 屋上庭園
# ロープブリッジ
# 廃墟
# 滑走路
# 砂場
# サウナ
# 学校
# 科学博物館
# サーバールーム
# 物置小屋
# 靴屋
# 店頭
# ショッピングモール/屋内
# シャワー
# スキーリゾート
# スキー場
# 空
# 超高層ビル
# スラム
# 雪原
# サッカー競技場
# 厩舎
# スタジアム/野球
# スタジアム/サッカー
# スタジアム/サッカー
# ステージ/屋内
# ステージ/アウトドア
# 階段
# 貯蔵室
# ストリート
# 地下鉄駅/プラットフォーム
# スーパーマーケット
# 寿司バー
# 沼地
# スイミングホール
# スイミングプール/屋内プール
# スイミングプール/屋外
# シナゴーグ/アウトドア
# テレビルーム
# テレビスタジオ
# 寺/アジア
# 王座の部屋
# チケット売り場
# トピアリーガーデン,人工的に造形された庭
# タワー
# 玩具屋
# 列車のインテリア
# 駅/プラットフォーム
# 樹木農場
# 樹上の家
# 溝,塹壕
# ツンドラ
# 水中/海洋深層
# ユーティリティルーム
# 谷
# 野菜園
# 獣医師のオフィス
# 高架橋
# 村
# ブドウ園
# 火山
# バレーボールコート/アウトドア
# 待合室
# ウォーターパーク,プール
# 給水塔
# 滝
# 給水口
# 波
# ウェットバー, ホームバー
# 小麦畑
# ウィンドファーム, 風力発電所
# 風車
# ヤード,芝庭
# ユースホステル
# 禅園
#
# ```
